# %% [markdown]
# <a href="https://colab.research.google.com/github/rachakondasaivarshini/GAN-PROGRAMS/blob/main/GAN_EXPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "R.sai varshini"
age = 19

print("Name :", name)
print("Age :", age)
for i in range(5):
    print(i)
    def greet():
        print("Welcome in GAN Lab")
    greet ()
    fruits=["Guava","Pineapple","Jackfruit"]
    print(fruits)
    import math
    print(math.sqrt(25))
# Out:
# Name : R.sai varshini
# Age : 19
# 0
# Welcome in GAN Lab
# ['Guava', 'Pineapple', 'Jackfruit']
# 5.0
# 1
# Welcome in GAN Lab
# ['Guava', 'Pineapple', 'Jackfruit']
# 5.0
# 2
# Welcome in GAN Lab
# ['Guava', 'Pineapple', 'Jackfruit']
# 5.0
# 3
# Welcome in GAN Lab
# ['Guava', 'Pineapple', 'Jackfruit']
# 5.0
# 4
# Welcome in GAN Lab
# ['Guava', 'Pineapple', 'Jackfruit']
# 5.0
