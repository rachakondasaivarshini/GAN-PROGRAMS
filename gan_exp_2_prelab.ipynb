# %% [markdown]
# <a href="https://colab.research.google.com/github/rachakondasaivarshini/GAN-PROGRAMS/blob/main/gan_exp_2_prelab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn
import cv2

print("All required packages are installed and ready to use.")
# Out:
# All required packages are installed and ready to use.
