# %% [markdown]
# <a href="https://colab.research.google.com/github/rachakondasaivarshini/GAN-PROGRAMS/blob/main/GAN_postlab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential

# Create sample image data
X = np.random.randint(0, 256, (500, 32, 32, 3))
y = np.random.randint(0, 43, 500)

# Split data
X_train, X_test = X[:400], X[400:]
y_train, y_test = y[:400], y[400:]

# CNN model
model = Sequential([
    layers.Rescaling(1./255, input_shape=(32, 32, 3)),
    layers.Conv2D(32, 3, activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation="relu"),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dense(43, activation="softmax")
])

# Compile
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Train
model.fit(X_train, y_train, epochs=3, validation_split=0.2)

# Test
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy:", accuracy)
print("CNN training completed successfully!")
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/preprocessing/data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.0281 - loss: 3.7813 - val_accuracy: 0.0500 - val_loss: 3.7323
# Epoch 2/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.0406 - loss: 3.7276 - val_accuracy: 0.0250 - val_loss: 3.7247
# Epoch 3/3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.0406 - loss: 3.7199 - val_accuracy: 0.0500 - val_loss: 3.7160
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0400 - loss: 3.8482
# Test Accuracy: 0.03999999910593033
# CNN training completed successfully!
